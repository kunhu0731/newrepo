# %%
#1家分站30天的營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([4435, 4374, 3159, 5185, 8832, 8424, 8375, 5572, 4539, 1246, 5033,
#        9974, 7559, 5322, 1394, 7380, 4760, 5706, 9772, 7471, 7003, 8821,
#        9898, 5353, 6807, 5889, 7171, 7995,  531, 7150], dtype=int32)

# %%
#累計每天這家店的營收
oneStoreCum = one_store.cumsum()
oneStoreCum
# Out:
# array([  4435,   8809,  11968,  17153,  25985,  34409,  42784,  48356,
#         52895,  54141,  59174,  69148,  76707,  82029,  83423,  90803,
#         95563, 101269, 111041, 118512, 125515, 134336, 144234, 149587,
#        156394, 162283, 169454, 177449, 177980, 185130])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), oneStoreCum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
