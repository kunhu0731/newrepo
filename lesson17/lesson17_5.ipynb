# 學生19   67   81   81  100  64
# 學生20  100   60   69   74  57
# 學生21   54   99   76   50  82
# 學生22   61   88   73   64  80
# 學生23   66   97   58   67  83
# 學生24   62   75   85   99  87
# 學生25   59   75   87   90  89
# 學生26   54   58   50   72  88
# 學生27   91   81   99   70  87
# 學生28   80   67   69   56  63
# 學生29   78  100   66   90  97
# 學生30   76   99   53   56  65
# 學生31   70   78   97   73  52
# 學生32   79   80   72   60  92
# 學生33   95   77   81   81  71
# 學生34   87   63   80   55  99
# 學生35   91   60   51   75  76
# 學生36   78   55   81   58  59
# 學生37   86   91  100   57  89
# 學生38   97   84   51   51  68
# 學生39   65   91   73   75  75
# 學生40   51   61   96   73  71
# 學生41   55   50   99   83  55
# 學生42   81   60   80   88  90
# 學生43  100   81   66   89  59
# 學生44   57   85   57   55  57
# 學生45   74   67   85   60  89
# 學生46   66   74   90   56  82
# 學生47   67   56   76   66  65
# 學生48   54  100   98   80  73
# 學生49   80   54   69   66  85
# 學生50   57  100   56   87  93

# %%
s = df1.loc['學生1']
less_than_60_series = s[s<60]
#取出不及格的科目
failing_subjects = less_than_60_series.index.tolist()
failing_subjects
#取出不及格科目的分數
failing_scores = less_than_60_series.tolist()
failing_scores
#建立一個Series,值要轉換為字串,如果有多個值則用逗號分隔
failing_scores_str = ','.join(map(str, failing_scores))
failing_subjects_str = ','.join(failing_subjects)
pd.Series([failing_scores_str, failing_subjects_str], index=['分數', '不及格科目'])
# Out:
# 分數       53
# 不及格科目    數學
# dtype: object

# %%
def apply_statistics(s):
    less_than_60_series = s[s<60]
    #不及格科目數量
    failing_subjects_count = less_than_60_series.count()
    #取出不及格的科目
    failing_subjects = less_than_60_series.index.tolist()
    
    #取出不及格科目的分數
    failing_scores = less_than_60_series.tolist()
    
    #建立一個Series,值要轉換為字串,如果有多個值則用逗號分隔
    failing_scores_str = ','.join(map(str, failing_scores))
    failing_subjects_str = ','.join(failing_subjects)
    return pd.Series([failing_subjects_count,failing_subjects_str,failing_scores_str], index=['不及格科目數量', '不及格科目', '分數'])


df2 = df1.apply(apply_statistics, axis=1)
df2
# Out:
#       不及格科目數量        不及格科目           分數
# 學生
# 學生1         1           數學           53
# 學生2         3     國文,自然,社會     53,58,54
# 學生3         1           國文           58
# 學生4         1           數學           59
# 學生5         2        英文,自然        58,51
# 學生6         1           社會           59
# 學生7         1           英文           50
# 學生8         1           自然           59
# 學生9         0
# 學生10        2        英文,社會        50,58
# 學生11        1           英文           52
# 學生12        3     國文,數學,社會     58,54,50
# 學生13        1           英文           58
# 學生14        1           數學           51
# 學生15        2        自然,社會        50,56
# 學生16        1           社會           52
# 學生17        2        國文,英文        56,55
# 學生18        2        英文,數學        57,55
# 學生19        0
# 學生20        1           社會           57
# 學生21        2        國文,自然        54,50
# 學生22        0
# 學生23        1           數學           58
# 學生24        0
# 學生25        1           國文           59
# 學生26        3     國文,英文,數學     54,58,50
# 學生27        0
# 學生28        1           自然           56
# 學生29        0
# 學生30        2        數學,自然        53,56
# 學生31        1           社會           52
# 學生32        0
# 學生33        0
# 學生34        1           自然           55
# 學生35        1           數學           51
# 學生36        3     英文,自然,社會     55,58,59
# 學生37        1           自然           57
# 學生38        2        數學,自然        51,51
# 學生39        0
# 學生40        1           國文           51
# 學生41        3     國文,英文,社會     55,50,55
# 學生42        0
# 學生43        1           社會           59
# 學生44        4  國文,數學,自然,社會  57,57,55,57
# 學生45        0
# 學生46        1           自然           56
# 學生47        1           英文           56
# 學生48        1           國文           54
# 學生49        1           英文           54
# 學生50        2        國文,數學        57,56

# %%
#df要和df2合併
df_merged = pd.concat([df, df2], axis=1)
df_merged

# %%
#df_merged請儲存為excel檔
df_merged.to_excel('df_merged.xlsx')
